# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# import data in pandas dataframe (change the file name to your local file)
data = pd.read_csv('logs/logs.csv', header = None)

# %%
print(data)
# Out:
# 0         1         2     3
# 0      0.033568 -0.160639 -0.374193  27.0
# 1      0.033803 -0.160589 -0.373910  27.0
# 2      0.000000  0.000000  0.000000  27.0
# 3     -0.000001 -0.000364 -0.000190  27.0
# 4      0.032673  0.000115  0.000237  28.0
# ...         ...       ...       ...   ...
# 99995  0.000000  0.000000  0.000000   0.0
# 99996  0.000000  0.000000  0.000000   0.0
# 99997  0.000000  0.000000  0.000000   0.0
# 99998  0.000000  0.000000  0.000000   0.0
# 99999  0.000000  0.000000  0.000000   0.0
#
# [100000 rows x 4 columns]

# %%
# remove all-zeros rows
data = data[(data.T != 0).any()]

# %%
print(data)
# Out:
# 0         1         2      3
# 0     0.033568 -0.160639 -0.374193   27.0
# 1     0.033803 -0.160589 -0.373910   27.0
# 2     0.000000  0.000000  0.000000   27.0
# 3    -0.000001 -0.000364 -0.000190   27.0
# 4     0.032673  0.000115  0.000237   28.0
# ...        ...       ...       ...    ...
# 3610  0.248630  0.004195 -0.038737  237.0
# 3611  0.241181  0.004563 -0.040176  237.0
# 3612  0.234264  0.003715 -0.040442  237.0
# 3613  0.224897  0.002514 -0.043661  237.0
# 3614  0.229115  0.011364 -0.042151  237.0
#
# [3615 rows x 4 columns]

# %%
# plot all timeseries
for i in data:
    plt.figure()
    data[i].plot()
